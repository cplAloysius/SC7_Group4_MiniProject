# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import OneHotEncoder

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk
#uncomment if required
#nltk.download('stopwords')
#nltk.download('punkt')

# %%
df = pd.read_csv('fake.csv')

# %%
#Create a new column 'post_engagement' which is the sum of the 'likes', 'comments', and 'shares' columns

sum_list = ['likes', 'comments', 'shares']
df['post_engagement'] = df[sum_list].sum(axis=1)

# %%
#Checking how many null entries in each column

df.isnull().sum()
# Out:
# uuid                     0
# ord_in_thread            0
# author                2424
# published                0
# title                  680
# text                    46
# language                 0
# crawled                  0
# site_url                 0
# country                176
# domain_rank           4223
# thread_title            12
# spam_score               0
# main_img_url          3643
# replies_count            0
# participants_count       0
# likes                    0
# comments                 0
# shares                   0
# type                     0
# post_engagement          0
# dtype: int64

# %%
#Zooming in on "country" column, "US" is the most common entry

df.country.value_counts()
# Out:
# US    10367
# GB      831
# RU      400
# DE      224
# FR      207
# TV      201
# EU      112
# CA      103
# IS      100
# ES      100
# NL       55
# ME       34
# IN       23
# BG       19
# CO       17
# LI       10
# IR        7
# EE        4
# ZA        3
# SG        2
# IO        1
# SE        1
# AU        1
# CH        1
# Name: country, dtype: int64

# %%
#Filling null entries in "country" column with "US" as it is the most common

df.country.fillna("US", inplace=True)

# %%
#Remove countries that have less than 20 entries

value_counts = df.country.value_counts()
to_remove = value_counts[value_counts<20].index
df.replace(to_remove, np.nan, inplace = True)

# %%
df.language.value_counts()
# Out:
# english       12403
# russian         203
# spanish         172
# german          111
# french           38
# arabic           22
# portuguese       11
# turkish          10
# italian           9
# ignore            7
# greek             4
# dutch             3
# norwegian         3
# finnish           1
# chinese           1
# polish            1
# Name: language, dtype: int64

# %%
#Remove all non-english entries as there are too few

df = df[df.language == 'english']

# %%
#Dropping columns that will not be used

df = df.drop(['uuid', 'language', 'likes', 'comments', 'shares', 'crawled', 'published', 'ord_in_thread', 'domain_rank', 'main_img_url', 'thread_title'], axis = 1)

# %%
#Removing rows with missing values

df = df.dropna()

# %%
#Too many 0s for spam_score

f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = df.spam_score, orient = "h", ax = axes[0])
sb.histplot(data = df.spam_score, ax = axes[1])
sb.violinplot(data = df.spam_score, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
#Remove 0 rows in spam_score to eliminate skewness

#df = df[df.spam_score != 0]
spam = pd.DataFrame(df['spam_score'])

# %%
f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = spam, orient = "h", ax = axes[0])
sb.histplot(data = spam, ax = axes[1])
sb.violinplot(data = spam, orient = "h", ax = axes[2])
# Out:
# <AxesSubplot:>

# %%
#Converting values of spam_score from numeric to categorical where 
#spam_score <= 0.3 is changed to 'low'
#0.3 < spam_score <= 0.6 is changed to 'medium'
#spam_score > 0.6 is changed to 'high'

df.loc[(df.spam_score <= 0.3) & (df.spam_score > 0), 'spam_score'] = 0.3
df.loc[(df.spam_score > 0.3) & (df.spam_score <= 0.6), 'spam_score'] = 0.6
df.loc[(df.spam_score > 0.6), 'spam_score'] = 1

df.loc[(df.spam_score == 0), 'spam_score'] = 'zero'
df.loc[(df.spam_score == 0.3), 'spam_score'] = 'low'
df.loc[(df.spam_score == 0.6), 'spam_score'] = 'medium'
df.loc[(df.spam_score == 1), 'spam_score'] = 'high'

# %%
spam = pd.DataFrame(df['spam_score'])

# %%
sb.catplot(y = "spam_score", data = spam, kind = "count")

# %%
# #stop_words are the words that we ignore
 
# stop_words = stopwords.words("english")

# #function to tokenize text and remove stopwords and punctuations

# def stemmer(txt):
#     txt=txt.lower()
#     words = word_tokenize(txt)
#     words = [w for w in words if w.isalpha()]
#     words = [w for w in words if not w in stop_words]
#     return( " ".join(words ))

# %%
# df["title"] = df["title"].apply(stemmer)
# df["text"] = df["text"].apply(stemmer)

# %%
text = df["title"].tolist()
vectorizer = TfidfVectorizer()
vectorizer.fit(text)

#dictionary of all the words in title
vectorizer.vocabulary_
# Out:
# {'muslims': 7617,
#  'busted': 1771,
#  'they': 11483,
#  'stole': 10942,
#  'millions': 7329,
#  'in': 5788,
#  'gov': 5021,
#  'benefits': 1300,
#  're': 9301,
#  'why': 12577,
#  'did': 3324,
#  'attorney': 992,
#  'general': 4878,
#  'loretta': 6855,
#  'lynch': 6912,
#  'plead': 8621,
#  'the': 11457,
#  'fifth': 4427,
#  'breaking': 1606,
#  'weiner': 12495,
#  'cooperating': 2646,
#  'with': 12643,
#  'fbi': 4344,
#  'on': 8018,
#  'hillary': 5430,
#  'email': 3848,
#  'investigation': 6044,
#  'pin': 8553,
#  'drop': 3650,
#  'speech': 10738,
#  'by': 1790,
#  'father': 4335,
#  'of': 7963,
#  'daughter': 2981,
#  'kidnapped': 6371,
#  'and': 693,
#  'killed': 6382,
#  'isis': 6092,
#  'have': 5284,
#  'voted': 12335,
#  'for': 4619,
#  'donald': 3550,
#  'trump': 11814,
#  '100percentfedup': 19,
#  'com': 2376,
#  'fantastic': 4298,
#  'point': 8663,
#  'plan': 8591,
#  'to': 11583,
#  'reform': 9421,
#  'healthcare': 5313,
#  'begins': 1264,
#  'bombshell': 1503,
#  'goes': 4980,
#  'absolutely': 326,
#  'berserk': 1316,
#  'protester': 9023,
#  'at': 959,
#  'rally': 9228,
#  'video': 12257,
#  'nypd': 7902,
#  'ready': 9318,
#  'make': 6975,
#  'arrests': 876,
#  'case': 1929,
#  'visited': 12306,
#  'pedophile': 8383,
#  'island': 6102,
#  'least': 6629,
#  'times': 11562,
#  'money': 7466,
#  'laundering': 6579,
#  'underage': 11964,
#  'sex': 10268,
#  'pay': 8357,
#  'play': 8608,
#  'proof': 8978,
#  'inappropriate': 5790,
#  'handling': 5218,
#  'classified': 2232,
#  'information': 5878,
#  'wow': 12705,
#  'whistleblower': 12554,
#  'tells': 11388,
#  'chilling': 2140,
#  'story': 10970,
#  'massive': 7116,
#  'voter': 12337,
#  'fraud': 4695,
#  'campaign': 1840,
#  'readies': 9314,
#  'lawsuit': 6596,
#  'against': 497,
#  'fl': 4511,
#  'sec': 10147,
#  'elections': 3809,
#  'critical': 2809,
#  'district': 3483,
#  'clinton': 2268,
#  'cleared': 2247,
#  'was': 12421,
#  'this': 11500,
#  'coordinated': 2648,
#  'last': 6553,
#  'minute': 7362,
#  'trick': 11771,
#  'energize': 3923,
#  'base': 1186,
#  'evil': 4096,
#  'supporters': 11144,
#  'yell': 12755,
#  'ck': 2211,
#  'burn': 1752,
#  'truck': 11808,
#  'daddy': 2930,
#  'fishing': 4499,
#  'yr': 12800,
#  'son': 10663,
#  'over': 8160,
#  'bumper': 1736,
#  'stickers': 10929,
#  'yikes': 12770,
#  'off': 7964,
#  'rails': 9213,
#  'pulls': 9079,
#  'howard': 5593,
#  'dean': 3008,
#  'say': 10031,
#  'goodbye': 5000,
#  'these': 11480,
#  '23': 144,
#  'hollywood': 5495,
#  'celebs': 1991,
#  'threatened': 11518,
#  'leave': 6630,
#  'let': 6685,
#  'hold': 5481,
#  'them': 11465,
#  'it': 6121,
#  'not': 7849,
#  'kidding': 6370,
#  'colleges': 2353,
#  'give': 4935,
#  'students': 11023,
#  'safe': 9935,
#  'spaces': 10706,
#  'cry': 2856,
#  'win': 12612,
#  'threaten': 11517,
#  'pro': 8909,
#  'chalkings': 2037,
#  'boom': 1522,
#  'math': 7130,
#  'shows': 10413,
#  'would': 12700,
#  'beaten': 1235,
#  'obama': 7913,
#  'romney': 9833,
#  'election': 3806,
#  'is': 6087,
#  'how': 5592,
#  'president': 8847,
#  'reagan': 9319,
#  'handled': 5215,
#  'protesters': 9024,
#  'negotiate': 7716,
#  'what': 12530,
#  'there': 11478,
#  'supporter': 11143,
#  'got': 5016,
#  'nuts': 7897,
#  'msnbc': 7570,
#  'reporter': 9569,
#  'covering': 2736,
#  'anti': 746,
#  'rioters': 9764,
#  'tomi': 11604,
#  'lahren': 6503,
#  'has': 5262,
#  'special': 10727,
#  'message': 7254,
#  'celebrities': 1989,
#  'who': 12563,
#  'said': 9944,
#  'move': 7546,
#  'canada': 1847,
#  'if': 5700,
#  'won': 12662,
#  'boycottcomedian': 1564,
#  'robert': 9798,
#  'deniro': 3163,
#  'wanted': 12389,
#  'punch': 9087,
#  'face': 4238,
#  'supports': 11146,
#  'now': 7866,
#  'wants': 12390,
#  'americans': 658,
#  'support': 11141,
#  'his': 5453,
#  'new': 7765,
#  'movie': 7553,
#  'he': 5298,
#  'never': 7761,
#  'sold': 10643,
#  'an': 675,
#  'original': 8101,
#  'painting': 8219,
#  'until': 12078,
#  'one': 8021,
#  'going': 4984,
#  'white': 12557,
#  'house': 5584,
#  'sorry': 10680,
#  'liberals': 6709,
#  'you': 12785,
#  'can': 1846,
#  'stop': 10954,
#  'petitions': 8466,
#  'popular': 8718,
#  'vote': 12334,
#  'mark': 7067,
#  'cuban': 2869,
#  'event': 4081,
#  'wins': 12626,
#  'no': 7810,
#  'doubt': 3587,
#  'market': 7069,
#  'tanks': 11317,
#  'so': 10617,
#  'here': 5388,
#  'really': 9331,
#  'happened': 5229,
#  'whose': 12576,
#  'brutal': 1690,
#  'beating': 1236,
#  'black': 1392,
#  'mob': 7414,
#  'caught': 1965,
#  'asks': 912,
#  'america': 655,
#  'suggest': 11098,
#  'blacks': 1401,
#  'are': 844,
#  'too': 11613,
#  'stupid': 11042,
#  'get': 4906,
#  'id': 5680,
#  'figure': 4434,
#  'out': 8127,
#  'use': 12134,
#  'internet': 5995,
#  'lol': 6833,
#  'british': 1662,
#  'wife': 12587,
#  'lib': 6704,
#  'actor': 397,
#  'will': 12603,
#  'be': 1222,
#  'warns': 12408,
#  'about': 316,
#  'elect': 3804,
#  'epic': 3990,
#  'tucker': 11851,
#  'carlson': 1907,
#  'demolishes': 3146,
#  'nyc': 7901,
#  'councilman': 2703,
#  'sanctuary': 9979,
#  'cities': 2198,
#  'funny': 4788,
#  'snl': 10606,
#  'solution': 10651,
#  'democrat': 3140,
#  'denial': 3159,
#  'space': 10705,
#  'everyone': 4088,
#  'calls': 1823,
#  'meeting': 7206,
#  'press': 8850,
#  'dresses': 3633,
#  'down': 3596,
#  'real': 9320,
#  'fake': 4273,
#  'news': 7769,
#  'networks': 7755,
#  'cnn': 2304,
#  'liar': 6702,
#  'should': 10401,
#  'ashamed': 902,
#  'oops': 8033,
#  'crybaby': 2857,
#  'hamilton': 5203,
#  'stars': 10867,
#  'lectured': 6635,
#  'pence': 8394,
#  'haven': 5285,
#  'years': 12753,
#  'bashing': 1192,
#  'reprimanded': 9578,
#  'live': 6798,
#  'interview': 6004,
#  'using': 12142,
#  'word': 12674,
#  'kellyanne': 6336,
#  'conway': 2634,
#  'shuts': 10426,
#  'cuomo': 2886,
#  'sharia': 10308,
#  'minneapolis': 7352,
#  'still': 10931,
#  'being': 1274,
#  'recruited': 9386,
#  'terrorists': 11425,
#  'sheriff': 10334,
#  'clarke': 2224,
#  'final': 4456,
#  'days': 2991,
#  'like': 6752,
#  'tenant': 11396,
#  'been': 1255,
#  'evicted': 4092,
#  'from': 4738,
#  'property': 8984,
#  'gonna': 4998,
#  'trash': 11731,
#  'place': 8583,
#  'way': 12449,
#  'door': 3570,
#  'crowd': 2834,
#  'chants': 2062,
#  'better': 1326,
#  'than': 11448,
#  '11': 28,
#  'dead': 2999,
#  'cops': 2655,
#  '12': 34,
#  'three': 11522,
#  'police': 8679,
#  'officers': 7979,
#  'ambushed': 653,
#  'same': 9972,
#  'weekend': 12482,
#  'redux': 9408,
#  'behind': 1271,
#  'probe': 8912,
#  'into': 6012,
#  'emails': 3851,
#  'party': 8313,
#  'corruption': 2683,
#  'directly': 3367,
#  'tied': 11545,
#  'disgraced': 3416,
#  'dnc': 3513,
#  'consultant': 2574,
#  'partners': 8309,
#  'crime': 2792,
#  'goldman': 4991,
#  'sachs': 9926,
#  'clintons': 2270,
#  'wall': 12376,
#  'street': 10993,
#  'color': 2365,
#  'rev': 9673,
#  'agit': 514,
#  'prop': 8980,
#  'george': 4898,
#  'soros': 10679,
#  'moveon': 7551,
#  'agitators': 515,
#  'march': 7050,
#  'as': 899,
#  'billionaire': 1357,
#  'instigator': 5950,
#  'sued': 11086,
#  'henningsen': 5378,
#  'us': 12129,
#  'protests': 9028,
#  'similar': 10463,
#  'revolutions': 9707,
#  'abroad': 321,
#  'cbs': 1975,
#  '60': 237,
#  'minutes': 7363,
#  'withheld': 12646,
#  'appeal': 786,
#  'attacking': 978,
#  'minorities': 7356,
#  'ignored': 5705,
#  'reports': 9572,
#  'attacks': 979,
#  'flashback': 4522,
#  'kkk': 6410,
#  'smear': 10579,
#  'strategy': 10985,
#  'calling': 1822,
#  'recount': 9378,
#  'votes': 12339,
#  'battleground': 1208,
#  'states': 10879,
#  'hell': 5357,
#  'comes': 2387,
#  'frogtown': 4737,
#  'alt': 635,
#  'right': 9748,
#  'triumph': 11787,
#  'transhumanism': 11717,
#  'signs': 10452,
#  'executive': 4139,
#  'order': 8078,
#  'declaring': 3053,
#  'results': 9645,
#  'revote': 9709,
#  'planned': 8596,
#  'dec': 3028,
#  '19th': 105,
#  'abc': 299,
#  '2816': 161,
#  'pride': 8874,
#  'pig': 8535,
#  'farm': 4307,
#  'bridge': 1637,
#  'serco': 10225,
#  'zulu': 12839,
#  'server': 10239,
#  'snuff': 10615,
#  'patented': 8333,
#  'key': 6354,
#  '2817': 162,
#  'starnet': 10866,
#  'blackmail': 1398,
#  'patent': 8332,
#  'roger': 9816,
#  'stone': 10946,
#  'update': 12095,
#  'steal': 10898,
#  'exit': 4153,
#  'poll': 8696,
#  'program': 8945,
#  'globalist': 4952,
#  'establishment': 4034,
#  'creating': 2774,
#  'false': 4283,
#  'expectation': 4167,
#  'close': 2279,
#  'race': 9185,
#  'polls': 8700,
#  'then': 11469,
#  'rigging': 9747,
#  'voting': 12340,
#  'machines': 6929,
#  'meet': 7205,
#  'that': 11455,
#  'nationalistic': 7667,
#  'constitutional': 2569,
#  'free': 4702,
#  'awakening': 1046,
#  'rothschild': 9849,
#  'chances': 2050,
#  'stealing': 10899,
#  'shrinking': 10417,
#  'day': 2989,
#  'whole': 12566,
#  'system': 11268,
#  'rigged': 9746,
#  'exposed': 4200,
#  'american': 656,
#  'people': 8409,
#  'fed': 4360,
#  'up': 12093,
#  'elitist': 3834,
#  'deviants': 3300,
#  'panicking': 8250,
#  '2818': 163,
#  'mumbai': 7593,
#  'visa': 12302,
#  'advocates': 469,
#  'control': 2615,
#  'government': 5023,
#  'reopens': 9539,
#  'foundation': 4662,
#  'israeli': 6112,
#  'pork': 8725,
#  'kosher': 6449,
#  'great': 5061,
#  'again': 496,
#  'maga': 6944,
#  'doj': 3538,
#  'tried': 11775,
#  'squash': 10820,
#  'comey': 2389,
#  'letter': 6689,
#  'congress': 2526,
#  'scott': 10096,
#  'bennett': 1304,
#  'army': 867,
#  'terrorist': 11424,
#  'threat': 11516,
#  'finance': 4458,
#  'analyst': 679,
#  'under': 11963,
#  'dov': 3594,
#  'zakheim': 12810,
#  'gross': 5097,
#  'perversion': 8453,
#  'justice': 6286,
#  'ubs': 11913,
#  'brad': 1574,
#  'birkenfeld': 1377,
#  'worked': 12679,
#  'cia': 2180,
#  'edward': 3770,
#  'snowden': 10610,
#  'financing': 4462,
#  'banks': 1154,
#  'hsbc': 5599,
#  'represented': 9575,
#  'covington': 2739,
#  'burling': 1751,
#  'employer': 3887,
#  'eric': 4012,
#  'holder': 5482,
#  'lanny': 6530,
#  'breuer': 1621,
#  'michael': 7283,
#  'chertoff': 2119,
#  'demand': 3130,
#  'accountability': 357,
#  'your': 12789,
#  'representatives': 9574,
#  'do': 3515,
#  'forgive': 4638,
#  'msm': 7569,
#  'media': 7191,
#  'our': 8121,
#  'job': 6221,
#  'coming': 2396,
#  'clearer': 2248,
#  'focus': 4583,
#  'or': 8074,
#  'broke': 1672,
#  'stack': 10835,
#  'resignation': 9611,
#  'letters': 6690,
#  'furious': 4789,
#  'agents': 507,
#  'collapsing': 2342,
#  'true': 11812,
#  '2820': 164,
#  'servers': 10240,
#  'boeing': 1484,
#  'pimps': 8552,
#  'flight': 4540,
#  'insiders': 5930,
#  'expose': 4199,
#  'ring': 9757,
#  'hacked': 5165,
#  'missing': 7387,
#  'link': 6775,
#  'discovered': 3398,
#  'sings': 10479,
#  'bird': 1375,
#  'dickileak': 3317,
#  'provides': 9038,
#  'huma': 5616,
#  'sequestered': 10222,
#  'mount': 7535,
#  'weather': 12468,
#  'after': 491,
#  '65': 244,
#  '000': 1,
#  'found': 4661,
#  'longer': 6841,
#  'together': 11591,
#  'prime': 8881,
#  'minster': 7360,
#  'john': 6227,
#  'channeling': 2058,
#  'dollars': 3542,
#  'taxpayer': 11345,
#  'ethically': 4045,
#  'compromised': 2459,
#  'explanation': 4185,
#  'opened': 8039,
#  'mails': 6966,
#  'peter': 8462,
#  'kadzik': 6294,
#  'ally': 623,
#  'podesta': 8650,
#  'very': 12231,
#  'friend': 4723,
#  'take': 11286,
#  'charge': 2070,
#  'abedin': 303,
#  'words': 12676,
#  'extraordinary': 4220,
#  'claims': 2217,
#  'needs': 7709,
#  'banished': 1146,
#  'when': 12536,
#  'talking': 11305,
#  'extraterrestrials': 4222,
#  'we': 12453,
#  'know': 6430,
#  'truth': 11837,
#  'ufo': 11918,
#  'east': 3737,
#  'valley': 12172,
#  'az': 1060,
#  'night': 7799,
#  'nugget': 7880,
#  'files': 4439,
#  'fastwalkers': 4329,
#  'dsp': 3664,
#  'emp': 3882,
#  'forthcoming': 4652,
#  'kids': 6376,
#  'made': 6935,
#  'school': 10074,
#  'congressmen': 2529,
#  'turned': 11877,
#  'radio': 9203,
#  'host': 5570,
#  'joe': 6224,
#  'walsh': 12381,
#  'recklessly': 9361,
#  'talks': 11306,
#  'muskets': 7614,
#  'loses': 6860,
#  'two': 11901,
#  'powerful': 8781,
#  'quakes': 9140,
#  'hit': 5460,
#  'italy': 6123,
#  'within': 12648,
#  'hours': 5583,
#  'bill': 1353,
#  'weld': 12504,
#  'encourges': 3902,
#  'little': 6797,
#  'blue': 1459,
#  'balls': 1133,
#  'finally': 4457,
#  'my': 7625,
#  'first': 4496,
#  'thread': 11515,
#  'russia': 9905,
#  'puzzled': 9126,
#  'norways': 7843,
#  'decision': 3046,
#  'marines': 7064,
#  'influencing': 5868,
#  'machine': 6928,
#  'magnus': 6956,
#  'olsens': 8009,
#  'blood': 1448,
#  'isnt': 6108,
#  'observer': 7930,
#  'evidence': 4094,
#  'eyewitness': 4231,
#  'accounts': 359,
#  'counted': 2708,
#  'ufos': 11919,
#  'watch': 12430,
#  'mission': 7388,
#  'impossible': 5777,
#  'registration': 9444,
#  'starts': 10874,
#  'indiana': 5827,
#  'autistic': 1021,
#  'nanobots': 7651,
#  'causing': 1970,
#  'overwhelming': 8179,
#  'depression': 3206,
#  'far': 4300,
#  'end': 3904,
#  'yet': 12765,
#  'another': 731,
#  'wrong': 12724,
#  'touchscreen': 11646,
#  'calibration': 1815,
#  'master': 7118,
#  'estate': 4035,
#  'come': 2383,
#  'all': 601,
#  'pander': 8242,
#  'hispanics': 5455,
#  'some': 10658,
#  'whoppers': 12573,
#  'univision': 12031,
#  'disabled': 3374,
#  'spin': 10766,
#  'put': 9120,
#  'iv': 6130,
#  '20k': 132,
#  'wire': 12631,
#  'transfer': 11706,
#  'belize': 1286,
#  'returned': 9667,
#  'trumps': 11832,
#  'walk': 12370,
#  'fame': 4287,
#  'star': 10861,
#  'destroyed': 3255,
#  'sledgehammer': 10541,
#  'pick': 8520,
#  'family': 4290,
#  'guy': 5154,
#  'gone': 4996,
#  'mexico': 7274,
#  'declares': 3052,
#  'marijuana': 7059,
#  'human': 5617,
#  'supreme': 11155,
#  'court': 2728,
#  'chena': 2115,
#  'river': 9784,
#  'fairbanks': 4269,
#  'alaska': 572,
#  'swimming': 11237,
#  'beast': 1231,
#  'tape': 11322,
#  'officially': 7982,
#  'lays': 6603,
#  'deal': 3004,
#  'im': 5724,
#  'bloody': 1450,
#  'wankah': 12384,
#  'teotihuacan': 11406,
#  'california': 1817,
#  'stolen': 10943,
#  'bernie': 1312,
#  'sanders': 9981,
#  'hyperloop': 5661,
#  'time': 11559,
#  'does': 3533,
#  'nothing': 7852,
#  'pac': 8193,
#  'rep': 9540,
#  'admits': 436,
#  'suppression': 11150,
#  'targeting': 11328,
#  'suburban': 11064,
#  'mothers': 7527,
#  'strong': 11013,
#  'wait': 12360,
#  'she': 10322,
#  'investigator': 6047,
#  'max': 7147,
#  'spiers': 10756,
#  'vomiting': 12331,
#  'liquid': 6783,
#  'policy': 8683,
#  'syria': 11264,
#  'lead': 6607,
#  'world': 12685,
#  'war': 12392,
#  'julian': 6271,
#  'assange': 918,
#  'surfaces': 11161,
#  'speaks': 10725,
#  'argentina': 848,
#  'conference': 2497,
#  'via': 12240,
#  'telephone': 11381,
#  'mr': 7564,
#  'smith': 10587,
#  'part': 8297,
#  'main': 6967,
#  'guide': 5130,
#  'paradoxroutine': 8271,
#  'erb': 4007,
#  'vs': 12348,
#  'tonopah': 11609,
#  'test': 11433,
#  'range': 9244,
#  'google': 5004,
#  'earth': 3730,
#  'imagery': 5727,
#  '22': 138,
#  '2016': 124,
#  'wikileaks': 12593,
#  'needed': 7708,
#  'someone': 10660,
#  'sober': 10623,
#  'her': 5380,
#  '30': 173,
#  'afternoon': 494,
#  'looking': 6844,
#  'beyond': 1332,
#  'november': 7865,
#  '8th': 275,
#  'song': 10664,
#  'oligarchy': 8005,
#  'doom': 3566,
#  'more': 7499,
#  'footage': 4611,
#  'operation': 8046,
#  'high': 5409,
#  'jump': 6273,
#  'hitler': 5463,
#  'pilots': 8549,
#  'experience': 4173,
#  'moon': 7488,
#  'fell': 4380,
#  'heaven': 5333,
#  'mandela': 7016,
#  'effect': 3773,
#  'overlooked': 8166,
#  '33': 185,
#  'year': 12751,
#  'old': 7998,
#  'man': 7006,
#  'ascended': 900,
#  'shadow': 10279,
#  'south': 10693,
#  'korea': 6446,
#  'mary': 7093,
#  'rodwells': 9813,
#  'book': 1518,
#  'netflixs': 7752,
#  'ceo': 2014,
#  'says': 10034,
#  'entertainment': 3970,
#  'pills': 8547,
#  'could': 2698,
#  'next': 7781,
#  'big': 1344,
#  'thing': 11488,
#  'release': 9481,
#  '20': 109,
#  'declare': 3050,
#  'myself': 7627,
#  'conscientious': 2543,
#  'objector': 7923,
#  'heartless': 5325,
#  'cuts': 2913,
#  'sweet': 11231,
#  'grannys': 5049,
#  'water': 12436,
#  'supply': 11139,
#  'jubilee': 6262,
#  'mercy': 7246,
#  'ends': 3917,
#  'following': 4600,
#  'judgment': 6265,
#  'northrop': 7841,
#  'unveils': 12088,
#  'sixth': 10499,
#  'gen': 4874,
#  'fighter': 4429,
#  'concept': 2471,
#  'britain': 1659,
#  'send': 10203,
#  'hundreds': 5630,
#  'troops': 11797,
#  'border': 1530,
#  'cold': 2335,
#  'tension': 11401,
#  'escalates': 4023,
#  'nasa': 7657,
#  'films': 4452,
#  'flying': 4580,
#  'past': 8328,
#  'putin': 9121,
#  'unrealistic': 12059,
#  'impending': 5755,
#  'conspiracy': 2561,
#  'theories': 11472,
#  'deliverd': 3121,
#  'anonymously': 730,
#  'secret': 10153,
#  'messages': 7255,
#  'hidden': 5404,
#  'spam': 10708,
#  'must': 7619,
#  'impeach': 5751,
#  'hand': 5209,
#  'universe': 12027,
#  'hologram': 5498,
#  'virtual': 12296,
#  'reality': 9325,
#  'but': 1775,
#  'god': 4976,
#  'tom': 11601,
#  'delonge': 3124,
#  'changing': 2056,
#  'cynical': 2922,
#  'views': 12265,
#  'youth': 12793,
#  'towards': 11655,
#  'islam': 6093,
#  'only': 8028,
#  'peace': 8370,
#  'gateway': 4855,
#  'deep': 3068,
#  'forget': 4635,
#  'october': 7959,
#  'surprise': 11171,
#  'anyone': 763,
#  'help': 5364,
#  'meaning': 7175,
#  'mystery': 7631,
#  'playing': 8614,
#  'card': 1894,
#  'planet': 8595,
#  'nine': 7806,
#  'images': 5728,
#  'reveal': 9675,
#  'crashed': 2762,
#  'schiaparelli': 10067,
#  'mars': 7082,
#  'lander': 6517,
#  'best': 1318,
#  'forgotten': 4640,
#  'ehhh': 3790,
#  'conquers': 2540,
#  'steps': 10912,
#  'evp': 4105,
#  'want': 12388,
#  '2nd': 172,
#  'opinion': 8051,
#  'obamacare': 7914,
#  'meant': 7177,
#  'fail': 4262,
#  'usher': 12140,
#  'run': 9893,
#  'socialist': 10628,
#  'health': 5312,
#  'care': 1899,
#  'moment': 7455,
#  'realised': 9322,
#  'homeless': 5505,
#  'bombing': 1501,
#  'suspect': 11191,
#  'uc': 11914,
#  'berkeley': 1307,
#  'sjws': 10505,
#  'build': 1712,
#  'block': 1437,
#  'campus': 1844,
#  'endorses': 3915,
#  'latest': 6560,
#  'unveil': 12086,
#  'bullying': 1733,
#  'futilitys': 4793,
#  'democrats': 3142,
#  'racist': 9191,
#  'uneducated': 11993,
#  'red': 9391,
#  'necks': 7705,
#  'folding': 4593,
#  'wing': 12620,
#  'hack': 5164,
#  'youtube': 12797,
#  'purse': 9113,
#  'shame': 10293,
#  'journalists': 6256,
#  'presstitutes': 8853,
#  'their': 11462,
#  'madam': 6933,
#  'mike': 7307,
#  'pences': 8395,
#  'plane': 8592,
#  'slides': 10549,
#  'runway': 9898,
#  'laguardia': 6502,
#  'gop': 5007,
#  'vp': 12346,
#  'candidate': 1859,
#  'skids': 10508,
#  'airport': 551,
#  'oregon': 8085,
#  'standoff': 10859,
#  'leaders': 6609,
#  'acquitted': 381,
#  'malheur': 6992,
#  'wildlife': 12601,
#  'refuge': 9426,
#  'takeover': 11291,
#  'relying': 9497,
#  'enough': 3953,
#  'indicate': 5829,
#  'concern': 2473,
#  'defense': 3088,
#  'its': 6128,
#  'giant': 4916,
#  'middle': 7296,
#  'finger': 4471,
#  'washington': 12423,
#  'dc': 2994,
#  'bbc': 1219,
#  'nato': 7675,
#  'sends': 10205,
#  'lasers': 6549,
#  'truly': 11813,
#  'upon': 12105,
#  'ice': 5672,
#  'cube': 2870,
#  'loves': 6876,
#  ...}

# %%
vectorizer = TfidfVectorizer(min_df=2,ngram_range=(2, 3))
X_tfidf = vectorizer.fit_transform(df['title'])
Xtfidf2 = vectorizer.fit_transform(df['text'])

# %%
# Out:
# <9504x1380375 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8157720 stored elements in Compressed Sparse Row format>
